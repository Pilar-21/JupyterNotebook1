# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# - List the most commonly used programming languages in data science.
# - Catalogue the primary libraries employed in data science.
# - Enumerate the most frequently utilized data structures in data    science projects.
# - Provide a basic demonstration of widely used techniques in Python.
# - Visualize data using Python libraries.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Scala
# 6. Julia

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. Panda
# 2. NumPy
# 3. PyTorch
# 4. TensorFlow
# 5. Matplotlib
# 6. Apache
# 7. Keras

# %% [markdown]
# ### Data Science Tools

# %% [markdown]
# | Orden lista | Data Science Tools |
# | -------------| ------ |
# | 01 | Jupyter Notebook |
# | 02| RStudio |
# | 03 | Visual Studio Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers:
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutos = 200
horas = minutos / 60
print(horas, "horas")
# Out:
# 3.3333333333333335 horas

# %% [markdown]
# ## Author
# *María del Pilar Seijas Alcaraz*
